# %%
from PIL import Image
import numpy as np
from IPython.display import display, Markdown
from pynq import Xlnk
from pynq import Overlay

# %%
# resize_design = Overlay("bitstream/resize.bit")

resize_design = Overlay("./resize.bit")
# Out:
# /usr/local/lib/python3.6/dist-packages/pynq/pl_server/device.py:594: UserWarning: Users will not get PARAMETERS / REGISTERS information through TCL files. HWH file is recommended.
#   warnings.warn(message, UserWarning)

# %%
resize_design.ip_dict
# Out:
# {'axi_dma_0': {'addr_range': 65536,
#   'device': <pynq.pl_server.device.XlnkDevice at 0xb00d1b10>,
#   'driver': pynq.lib.dma.DMA,
#   'fullpath': 'axi_dma_0',
#   'gpio': {},
#   'interrupts': {},
#   'mem_id': 'SEG_axi_dma_0_Reg',
#   'phys_addr': 1077936128,
#   'state': None,
#   'type': 'xilinx.com:ip:axi_dma:7.1'},
#  'resize_accel_0': {'addr_range': 65536,
#   'device': <pynq.pl_server.device.XlnkDevice at 0xb00d1b10>,
#   'driver': pynq.overlay.DefaultIP,
#   'fullpath': 'resize_accel_0',
#   'gpio': {},
#   'interrupts': {},
#   'mem_id': 'SEG_resize_accel_0_Reg',
#   'phys_addr': 1136656384,
#   'state': None,
#   'type': 'xilinx.com:hls:resize_accel:1.0'}}

# %%
dma = resize_design.axi_dma_0
resizer = resize_design.resize_accel_0
# Out:
# /usr/local/lib/python3.6/dist-packages/pynq/lib/dma.py:200: UserWarning: Failed to find parameter c_sg_length_width; users should really use *.hwh files for overlays.
#   warnings.warn(message, UserWarning)

# %%
image_path = "./images/paris.jpg"
original_image = Image.open(image_path)
original_image.load()

# %%
input_array = np.array(original_image)

# %%
input_image = Image.fromarray(input_array)
display(input_image)

def printmd(string):
    display(Markdown('<h1 style="color:DeepPink"> {}</h1>'.format(string)))
# Out:
# <PIL.Image.Image image mode=RGB size=640x360 at 0xB00AAC50>

# %%
old_width, old_height = original_image.size
printmd("Image size: {}x{} pixels.".format(old_width, old_height))
# Out:
# <h1 style="color:DeepPink"> Image size: 640x360 pixels.</h1>

# %%
resize_factor = 6
new_width, new_height = int(old_width/resize_factor), int(old_height/resize_factor)

# %%
# %%timeit
resized_image_sw = original_image.resize((new_width, new_height), Image.BILINEAR)
# Out:
# 100 loops, best of 3: 13.9 ms per loop

# %%
resized_image_sw = original_image.resize((new_width, new_height), Image.BILINEAR)

# %%
output_array_sw = np.array(resized_image_sw)
result_sw = Image.fromarray(output_array_sw)
display(result_sw)
# Out:
# <PIL.Image.Image image mode=RGB size=106x60 at 0xAFC65150>

# %%
width_sw, height_sw = resized_image_sw.size
printmd("Image size resized in SW: {}x{} pixels.".format(width_sw, height_sw))
# Out:
# <h1 style="color:DeepPink"> Image size resized in SW: 106x60 pixels.</h1>

# %%
xlnk = Xlnk()
in_buffer = xlnk.cma_array(shape=(old_height, old_width, 3), dtype=np.uint8, cacheable=1)
out_buffer = xlnk.cma_array(shape=(new_height, new_width, 3), dtype=np.uint8, cacheable=1)

# %%
in_buffer[:] = input_array
buf_image = Image.fromarray(in_buffer)
display(buf_image)
printmd("Image size: {}x{} pixels.".format(old_width, old_height))
# Out:
# <PIL.Image.Image image mode=RGB size=640x360 at 0xAFC65FB0>
# <h1 style="color:DeepPink"> Image size: 640x360 pixels.</h1>

# %%
resizer.write(0x10, old_height) # src rows
resizer.write(0x18, old_width)  # src cols
resizer.write(0x20, new_height) # dst rows
resizer.write(0x28, new_width)  # dst cols

def run_kernel():
    dma.sendchannel.transfer(in_buffer)
    dma.recvchannel.transfer(out_buffer)
    resizer.write(0x00,0x81)
    dma.sendchannel.wait()
    dma.recvchannel.wait()

run_kernel()

result = Image.fromarray(out_buffer)
display(result)
printmd("Resized in Hardware(PL): {}x{} pixels.".format(new_width, new_height))
# Out:
# <PIL.Image.Image image mode=RGB size=106x60 at 0xAFC65CF0>
# <h1 style="color:DeepPink"> Resized in Hardware(PL): 106x60 pixels.</h1>

# %%
# %%timeit

resizer.write(0x10, old_height) # src rows
resizer.write(0x18, old_width)  # src cols
resizer.write(0x20, new_height) # dst rows
resizer.write(0x28, new_width)  # dst cols

def run_kernel():
    dma.sendchannel.transfer(in_buffer)
    dma.recvchannel.transfer(out_buffer)
    resizer.write(0x00,0x81)
    dma.sendchannel.wait()
    dma.recvchannel.wait()

run_kernel()
# Out:
# 100 loops, best of 3: 8.68 ms per loop

# %%
xlnk.xlnk_reset()
